# %%
#install.packages("httr")

#Require the package so you can use it
require("httr")
# Out:
# Loading required package: httr

# %%
#install.packages("jsonlite")

#Require the package so you can use it
require("jsonlite")
# Out:
# Loading required package: jsonlite
# Warning message:
# "package 'jsonlite' was built under R version 3.5.3"

# %%
networks <- "N_638948197133241698"

# %%
base <- "https://api.meraki.com/api/v0/networks/N_638948197133241698"

# %%
getNetworks <- GET(base, add_headers("x-cisco-meraki-api-key" = "b625da6fedf3a8092f4cde15973c9a3c0ca74000",
                                    "Accept"="*/*"))

# %%
getNetworks_text <- content(getNetworks, "text")

# %%
getNetworks_json <- fromJSON(getNetworks_text, flatten = TRUE)

# %%
getNetworks_frame <- as.data.frame(getNetworks_json)

# %%
getNetworks_frame
# Out:
#   id                   organizationId     type     productTypes name
# 1 N_638948197133241698 638948197133191082 wireless wireless     BIG DATA
#   timeZone          tags disableMyMerakiCom disableRemoteStatusPage
# 1 America/Guatemala      FALSE              TRUE

# %%
base <- "https://api.meraki.com/api/v0/networks/N_638948197133241698/clients"

# %%
getClients <- GET(base, add_headers("x-cisco-meraki-api-key" = "b625da6fedf3a8092f4cde15973c9a3c0ca74000",
                                    "Accept"="*/*"))

# %%
getClients_text <- content(getClients, "text")

# %%
getClients_json <- fromJSON(getClients_text, flatten = TRUE)

# %%
getNetworks_frame <- as.data.frame(getNetworks_json)

# %%
getNetworks_frame
# Out:
#    id      mac               description
# 1  k8347be 10:02:b5:78:63:1f LAPTOP-LC0GLMRU
# 2  k87634f a0:57:e3:39:e4:a4 HUAWEI_P20-2fc41e813db232
# 3  k0e6b48 44:03:2c:d3:e0:cd DESKTOP-KTCIN4T
# 4  k0e91d8 44:c3:46:af:84:cb Android-2
# 5  k0ed144 cc:2f:71:e0:fa:5b ec00ac35-4d11-4fcd-8240-00ff1a6236d8
# 6  k8d7dc1 90:63:3b:ca:cb:cf Android
# 7  k8ee7a3 a8:db:03:25:5b:ea Galaxy-S10
# 8  k8f3466 a8:7d:12:a3:b9:97 HUAWEI_P20_lite-15839c655
# 9  k944756 e4:a7:c5:b5:c7:4d HUAWEI_P20-5265abc08733e5
# 10 k9e21c9 6c:c7:ec:4e:3a:84 Galaxy-Note8
#    ip             ip6 user firstSeen            lastSeen
# 1  10.131.71.190  NA  NA   2019-11-11T16:50:02Z 2019-11-15T17:20:06Z
# 2  10.135.99.79   NA  NA   2019-11-11T17:20:27Z 2019-11-15T17:20:06Z
# 3  10.14.107.72   NA  NA   2019-11-11T16:50:02Z 2019-11-15T17:20:06Z
# 4  10.14.145.216  NA  NA   2019-11-11T17:20:27Z 2019-11-15T17:20:06Z
# 5  10.14.209.68   NA  NA   2019-11-11T16:48:28Z 2019-11-15T17:20:06Z
# ...

# %%
base <- "https://api.meraki.com/api/v0/networks/N_638948197133241698/clients/k8347be/trafficHistory"

# %%
getClientsTraffic <- GET(base, add_headers("x-cisco-meraki-api-key" = "b625da6fedf3a8092f4cde15973c9a3c0ca74000",
                                    "Accept"="*/*"))

# %%
getClientsTraffic_text <- content(getClientsTraffic, "text")

# %%
getClientsTraffic_text_json <- fromJSON(getClientsTraffic_text, flatten = TRUE)

# %%
getClientsTraffic_text_json
# Out:
#     ts         application
# 1   1573516800 SSH
# 2   1573516800 Gmail
# 3   1573516800 Google HTTPS
# 4   1573516800 Google HTTPS
# 5   1573516800 Software updates
# 6   1573516800 Software updates
# 7   1573516800 Software updates
# 8   1573516800 Google
# 9   1573516800 Google
# 10  1573516800 Google
# 11  1573516800 Ubuntu
# 12  1573516800 Ubuntu
# 13  1573516800 YouTube
# 14  1573516800 microsoft.com
# 15  1573516800 microsoft.com
# 16  1573516800 microsoft.com
# 17  1573516800 microsoft.com
# 18  1573516800 microsoft.com
# 19  1573516800 microsoft.com
# 20  1573516800 microsoft.com
# 21  1573516800 microsoft.com
# 22  1573516800 microsoft.com
# 23  1573516800 microsoft.com
# 24  1573516800 amazon.com
# 25  1573516800 Twitter
# 26  1573516800 Twitter
# 27  1573516800 Twitter
# 28  1573516800 Twitter
# 29  1573516800 CDNs
# 30  1573516800 Miscellaneous web
# ... ...        ...
# 266 1573776000 Miscellaneous secure web
# 267 1573776000 Miscellaneous secure web
# ...

# %%
getClientsTraffic_frame <- as.data.frame(getClientsTraffic_text_json)

# %%
getClientsTraffic_frame
# Out:
#     ts         application
# 1   1573516800 SSH
# 2   1573516800 Gmail
# 3   1573516800 Google HTTPS
# 4   1573516800 Google HTTPS
# 5   1573516800 Software updates
# 6   1573516800 Software updates
# 7   1573516800 Software updates
# 8   1573516800 Google
# 9   1573516800 Google
# 10  1573516800 Google
# 11  1573516800 Ubuntu
# 12  1573516800 Ubuntu
# 13  1573516800 YouTube
# 14  1573516800 microsoft.com
# 15  1573516800 microsoft.com
# 16  1573516800 microsoft.com
# 17  1573516800 microsoft.com
# 18  1573516800 microsoft.com
# 19  1573516800 microsoft.com
# 20  1573516800 microsoft.com
# 21  1573516800 microsoft.com
# 22  1573516800 microsoft.com
# 23  1573516800 microsoft.com
# 24  1573516800 amazon.com
# 25  1573516800 Twitter
# 26  1573516800 Twitter
# 27  1573516800 Twitter
# 28  1573516800 Twitter
# 29  1573516800 CDNs
# 30  1573516800 Miscellaneous web
# ... ...        ...
# 266 1573776000 Miscellaneous secure web
# 267 1573776000 Miscellaneous secure web
# ...
